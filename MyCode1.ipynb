# %%
''' CURRENT OBJECTIVE: Eliminating the red part from the datasheet '''

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
raw_img = cv.imread(r'C:\Users\DARPAN\Documents\College\6th Semester\BSc Project (DSE6)\Data\302_0007.png')
raw_img_RGB = cv.cvtColor(raw_img, cv.COLOR_BGR2RGB)
plt.xticks([]), plt.yticks([])
plt.imshow(raw_img)
plt.imshow(raw_img_RGB)
